# %% [markdown]
# <a href="https://colab.research.google.com/github/anhkiet287/HK252-CO4337-DATN/blob/main/notebooks/wandb_logging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/anhkiet287/HK252-CO4337-DATN.git
# Out:
# Cloning into 'HK252-CO4337-DATN'...
# remote: Enumerating objects: 186, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 186 (delta 1), reused 6 (delta 1), pack-reused 174 (from 1)
# Receiving objects: 100% (186/186), 1.68 MiB | 2.67 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd HK252-CO4337-DATN
# !pip install -e ".[wandb]"
# Out:
# /content/HK252-CO4337-DATN
# Obtaining file:///content/HK252-CO4337-DATN
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 14.4 MB/s eta 0:00:00
# ...
#   Building editable for ardg (pyproject.toml) ... done
#   Created wheel for ardg: filename=ardg-0.1.0-0.editable-py3-none-any.whl size=2445 sha256=01fe56a6a9c5f9eb0119544b0a3f1b581e7dbe5446afca65d3f4bf6c93d5b017
# ...

# %%
import torch; print(torch.cuda.is_available(), torch.cuda.get_device_name(0))
# Out:
# True Tesla T4

# %%
import os, wandb # run this if want to use wandb and make sure set true in configs file in logging
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Find your API key here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: kietna (kietna-ho-chi-minh-city-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !python -u scripts/train.py --config configs/test_colab.yaml
# Out:
# wandb: Currently logged in as: kietna (kietna-ho-chi-minh-city-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run ge0tmzvk (0.2s)
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /content/HK252-CO4337-DATN/wandb/run-20260119_081804-ge0tmzvk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run test_colab
# wandb: ⭐️ View project at https://wandb.ai/kietna-ho-chi-minh-city-university-of-technology/ardg
# wandb: 🚀 View run at https://wandb.ai/kietna-ho-chi-minh-city-university-of-technology/ardg/runs/ge0tmzvk
# 100% 170M/170M [00:05<00:00, 28.8MB/s]
# [2026-01-19 08:18:18,735] INFO root: Starting epoch 1
# [2026-01-19 08:18:23,118] INFO root: step=50 metrics={'train_batch/loss': 2.0683956146240234, 'train_batch/acc': 0.25, 'train_batch/lr': 0.01}
# ...

# %%
# !python -u scripts/evaluate.py --config configs/test_colab.yaml --checkpoint /content/drive/MyDrive/ardg/HK252-CO4337-DATN/outputs/checkpoints/ta50.tar
# Out:
# wandb: Currently logged in as: kietna (kietna-ho-chi-minh-city-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run d22gez73 (0.3s)
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /content/HK252-CO4337-DATN/wandb/run-20260119_081949-d22gez73
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run test_colab
# wandb: ⭐️ View project at https://wandb.ai/kietna-ho-chi-minh-city-university-of-technology/ardg
# wandb: 🚀 View run at https://wandb.ai/kietna-ho-chi-minh-city-university-of-technology/ardg/runs/d22gez73
# [2026-01-19 08:20:03,558] INFO root: step=0 metrics={'val_clean/loss': 0.33581050753593444, 'val_clean/acc': 0.91, 'val_clean/n_samples': 1000, 'val_clean/device': 'cuda'}
# ...
